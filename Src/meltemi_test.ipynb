# %%
from openai import OpenAI

# %%
modelfile = """
Είσαι ένας μεταφραστής. Ο σκοπός σου είναι να μεταφράσεις από τα αγγλικά στα ελληνικά τα ονόματα των πινάκων και των στηλών μιας βάσης δεδομένων.
Ως είσοδος θα σου δίνονται:
Ο πίνακας με όλες του τις στήλες.

Παρακάτω θα σου δοθούν παραδείγματα ερωτήσεων και οι απαντήσεις που πρέπει να δώσεις.

Για παράδειγμα στην ερώτηση:

Μετέφρασε το όνομα του πίνακα "conference" ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: conference
Στήλες: conference name, cid, conference date

Πρέπει να απαντήσεις: "conference" = "Συνέδρειο"


Για παράδειγμα στην ερώτηση:

Μετέφρασε το όνομα του πίνακα "airport" ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: airport
Στήλες: aid, airport create date, num warehouses

Πρέπει να απαντήσεις: "airport" = "Αεροδρόμιο"


Για παράδειγμα στην ερώτηση:

Μετέφρασε το όνομα της στήλης "author name" ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: author
Στήλες: author id, author name, birth date, publisher

Πρέπει να απαντήσεις: "author name" = "Όνομα συγγραφέα"


Για παράδειγμα στην ερώτηση:

Μετέφρασε το όνομα της στήλης "author id" ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: author
Στήλες: author id, author, birth date, publisher

Πρέπει να απαντήσεις: "author id" = "Αναγνωριστικό συγγραφέα"



Για παράδειγμα στην ερώτηση:

Μετέφρασε το όνομα της στήλης "product" ώστε να ταιριάζει με τον παρακάτω πίνακα:

Πίνακας: products
Στήλες: pid, product, manufacture date, price

Πρέπει να απαντήσεις: "product" = "Προϊόν"


Για παράδειγμα στην ερώτηση:

Μετέφρασε το όνομα της στήλης "staff id" ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: staff
Στήλες: staff id, registration year, staff name, staff birthday

Πρέπει να απαντήσεις: "staff id" = "Aναγνωριστικό προσωπικού"


Για παράδειγμα στην ερώτηση:

Μετέφρασε το όνομα της στήλης "staff birthday" ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: staff
Στήλες: staffid, registration year, staff name, staff birthday

Πρέπει να απαντήσεις: "staff birthday" = "Έτος γέννησης"


Για παράδειγμα στην ερώτηση:

Μετέφρασε το όνομα της στήλης "square feet" ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: house
Στήλες: house id, square feet, construction year, facade

Πρέπει να απαντήσεις: "square feet" = "Τετραγωνικά μέτρα"


Για παράδειγμα στην ερώτηση:

Μετέφρασε το όνομα της στήλης "mid" στα ελληνικά ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: movie
Στήλες: mid, title, year, director, budget million, gross worldwide

Πρέπει να απαντήσεις: "mid" = "Αναγνωριστικό ταινίας"

Για να είναι καλύτερη η μετάφραση της στήλης να βασιστείς κυρίως στον πίνακα και στις στήλες του αλλά και σε όλες τις αγγλικές και ελληνικές σου γνώσεις.
Επειδή μεταφράζεις βάσεις δεδομένων και όχι κανονικό κείμενο, στήλες οι οποίες δεν αντιστοιχούν σε κάποια αγγλική λέξη και τελειώνουν με "id" αντιστοιχούν σε αναγνωριστικό (Για παράδειγμα pid, aid, jid).
Αν δεν μπορείς να βρείς κάποια μετάφραση, απάντησε με την καλύτερη δυνατή μετάφραση που μπορείς να βρεις χρησιμοποιώντας όλες σου τις ελληνικές και τις αγγλικές γνώσεις.
Για τις απαντήσεις σου να συμβουλεύεσαι τα παραδείγματα που έχουν δοθεί.

Απάντησε την ερώτηση, όσο καλύτερα μπορείς όπως τα παραδείγματα, χωρίς σχολιασμό, χωρίς να επηρεάζεσαι από τις προηγούμενες απαντήσεις σου.
"""

# %%
extra = """
Επειδή μεταφράζεις βάσεις δεδομένων και όχι κανονικό κείμενο, στήλες οι οποίες δεν αντιστοιχούν σε κάποια αγγλική λέξη και τελειώνουν με "id" αντιστοιχούν σε αναγνωριστικό (Για παράδειγμα pid, aid, jid).
Στις περιπτώσεις αυτές η μετάφραση θα πρέπει να περιέχει την λέξη αναγνωριστικό.
Αν μια λέξη δεν περιέχει το "id" η το "ID" δεν μπορεί να είναι αναγνωριστικό.

Μην διαλέξεις την κοντινότερη λέξη (η φράση) στην ελληνική γλώσσα, αλλά την πιο κατάλληλη για τον πίνακα που σου δίνεται. Αν αυτό δεν είναι εφικτό, διάλεξε την πιο κοντινή λέξη (η φράση) στην ελληνική γλώσσα.
Αν δεν μπορείς να βρείς κάποια μετάφραση, απάντησε με την καλύτερη δυνατή μετάφραση που μπορείς να βρεις χρησιμοποιώντας όλες σου τις ελληνικές και τις αγγλικές γνώσεις.
Για τις απαντήσεις σου να συμβουλεύεσαι τα παραδείγματα που έχουν δοθεί.
"""

# %%
test_questions = [

"""
Μετέφρασε το όνομα της στήλης "cid" στα ελληνικά ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: climber
Στήλες: cid, name, mountain_id, country, time, points
""",

"""
Μετέφρασε το όνομα της στήλης "country" στα ελληνικά ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: climber
Στήλες: cid, name, mountain_id, country, time, points
""",

"""
Μετέφρασε το όνομα της στήλης "points" στα ελληνικά ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: climber
Στήλες: cid, name, mountain_id, country, time, points
""",

"""
Μετέφρασε το όνομα της στήλης "mountain_id" στα ελληνικά ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: climber
Στήλες: cid, name, mountain_id, country, time, points
""",

"""
Μετέφρασε το όνομα της στήλης "clubname" στα ελληνικά ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: club
Στήλες: club, clubid, clubname, clubdesc, clublocation
""",

"""
Μετέφρασε το όνομα της στήλης "clubdesc" στα ελληνικά ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: club
Στήλες: club, clubid, clubname, clubdesc, clublocation
""",

"""
Μετέφρασε το όνομα της στήλης "clubid" στα ελληνικά ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: club
Στήλες: clubid, clubname, clubdesc, clublocation
""",

"""
Μετέφρασε το όνομα της στήλης "stuid" στα ελληνικά ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: student
Στήλες: stuid, lname, fname, age, sex
""",

"""
Μετέφρασε το όνομα της στήλης "fname" στα ελληνικά ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: student
Στήλες: stuid, lname, fname, age, sex
""",

"""
Μετέφρασε το όνομα της στήλης "sex" στα ελληνικά ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: student
Στήλες: stuid, lname, fname, age, sex
""",

"""
Μετέφρασε το όνομα της στήλης "company id" στα ελληνικά ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: comapny
Στήλες: company id, name, headquarters, industry, sales in million, assets in million
""",

"""
Μετέφρασε το όνομα της στήλης "headquarters" στα ελληνικά ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: comapny
Στήλες: company id, name, headquarters, industry, sales in million, assets in million
""",

"""
Μετέφρασε το όνομα της στήλης "industry" στα ελληνικά ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: comapny
Στήλες: company id, name, headquarters, industry, sales in million, assets in million
""",

"""
Μετέφρασε το όνομα της στήλης "assets in million" στα ελληνικά ώστε να ταιριάζει με τον παρακάτω πίνακα:
Πίνακας: comapny
Στήλες: company id, name, headquarters, industry, sales in million, assets in million
""",

]

# %%
question_no = 4

test_questions[question_no]
# Out:
# '\nΜετέφρασε το όνομα της στήλης "clubname" στα ελληνικά ώστε να ταιριάζει με τον παρακάτω πίνακα:\nΠίνακας: club\nΣτήλες: club, clubid, clubname, clubdesc, clublocation\n'

# %%
client = OpenAI(base_url='http://localhost:1234/v1', api_key='lm-studio')

completion = client.chat.completions.create(
    model="SHAHE/Meltemi-7B-Instruct-v1-GGUF",
    messages=[
        {"role": "system", "content": modelfile},
        {"role": "user", "content": test_questions[question_no]},
    ],
    max_tokens=50,
    temperature=0.3
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='\nΠρέπει να απαντήσεις: "clubname" = "Όνομα συλλόγου"', role='assistant', function_call=None, tool_calls=None)
